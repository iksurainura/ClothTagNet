# %%
import cv2
import pytesseract

img = cv2.imread('C:/Users/MSI/Documents/GitHub/ClothTagNet/fabric_classification/test/defects/PXL_20251008_151907341.MP.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# improve contrast
gray = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)[1]

text = pytesseract.image_to_string(
    gray,
    lang="eng",
    config="--oem 3 --psm 6"
)

print(text)

# %%
best_model=YOLO('runs/classify/train2/weights/best.pt')
